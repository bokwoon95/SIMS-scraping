# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import datetime
import os
import time
import re
import sys
import pandas as pd
from lxml import html

# declare global variables
driver = None
counter = None
limit = None
cached_list = None
df = None

# %%
def sanitize(s):
    return s.lower().replace(" ", "").replace("-", "").replace(",", "").replace(":", "").strip()

# %%
def prep_driver():
    """
    Sets up a webdriver instance of chrome and navigates to the appropriate webpage.
    Returns the driver instance (so it doesn't get garbage collected on function exit)
    """
    global driver
    global counter
    global limit
    global cached_list
    global df

    # Configure chrome webdriver
    if os.name == 'nt':
        chromedriver = "./chromedriver.exe"
    else:
        chromedriver = "./chromedriver"
    os.environ["webdriver.chrome.driver"] = chromedriver
    driver = webdriver.Chrome(chromedriver)

    # Navigate to SIMS website
    driver.get('https://sims.me.exova.com/SIMS/SIMS-MVC/DashBoard/Index')

    # Enter username and password
    selectElem=driver.find_element_by_id("UserName")
    selectElem.clear()
    selectElem.send_keys("vignesh.v")
    selectElem=driver.find_element_by_name("pwd")
    selectElem.clear()
    selectElem.send_keys("Adjan2017#")

    # Press 'Login'
    selectElem=driver.find_element_by_xpath('//*[@id="LoginMain"]/div/div[3]/form/button')
    selectElem.click()

    # Navigate to test method section
    driver.get('https://sims.me.exova.com/SIMS/SIMS-MVC/Product/Index#ProductSearchGrid')

    #Expand 'Test Search'
    selectElem=driver.find_element_by_xpath('//a[@href="#ProductSearchGrid"]')
    selectElem.click()
    return driver

# %%
def search(method):
    """Searches a test method and returns the results in a dataframe"""
    global driver
    global counter
    global limit
    global cached_list
    global df

    method_filename = method.replace(":","..") # Windows is unable to parse filenames with a colon ":", replace those with two dots ".." instead

    # if cached results for the method search already exists, return it instead of doing the serach again
    if method_filename in cached_list:
        print("")
        print("{} already exists in cached_list".format(method_filename))
        # if a csv file is empty, return an empty dataframe instead (to avoid exception when parsing an empty csv file)
        if os.path.getsize("./data/{}.csv".format(method_filename)) > 0:
            return pd.read_csv("./data/{}.csv".format(method_filename), header=None, index_col=None, escapechar="|")
        else:
            return pd.DataFrame()

    # Clear the search field
    selectElem=driver.find_element_by_xpath('//*[@id="ProductSearch"]/div[1]/div/table/thead/tr[2]/th[3]/span/span/span/input')
    selectElem.clear()
    selectElem.send_keys(Keys.ENTER)
    time.sleep(1)

    # Search the method
    selectElem=driver.find_element_by_xpath('//*[@id="ProductSearch"]/div[1]/div/table/thead/tr[2]/th[3]/span/span/span/input')
    selectElem.clear()
    selectElem.send_keys(method.strip())
    selectElem.send_keys(Keys.ENTER)
    selectElem=driver.find_element_by_xpath('//*[@id="ProductSearch"]/div[2]').click()
    time.sleep(2)

    # Obtain the table results from the page
    soup = BeautifulSoup(driver.page_source, features="lxml")
    t1 = soup.find("div", {"id":"ProductSearch"}).find("div", {"class":"k-grid-content"}).find("table").find("tbody")
    # i = 1

    # Send table's html to file for debugging purposes
    with open("output1.html", "w") as file:
        file.write(str(t1.prettify()))

    # Transcribe the html table into a dataframe
    tbl_list = []
    tmp_list = []
    for row in t1.findAll("tr"):
        i = 0
        tmp_list = []
        for cell in row.findAll("td"):
            if (i >= 3):
                break
            else:
                i += 1
                #print(i)
                tmp_list.append(cell.text.strip())
        #print(tmp_list)
        tbl_list.append(tmp_list)
    df = pd.DataFrame(tbl_list)

    # cache the results of this search into a csv file and update the cached_list
    df.to_csv("./data/{}.csv".format(method.replace(":","..")), header=None, index=None, escapechar="|")
    cached_list.append(method)
    print("")
    print("{} added to cached_list".format(method.replace(":","..")))

    return df

# %%
def first_pass(test_id, test_item, test_method):
    """
    searches for exact matches
    """
    global driver
    global counter
    global limit
    global cached_list
    global df

    if limit>0 and counter>=limit:
        counter+=1
        return "blank"

    # if the 'test_id' column of df isn't already filled with a test id then do a search
    if pd.notnull(test_id) and re.compile("[A-Z0-9]{6}").match(test_id):
        counter+=1
        return test_id
    res=search(test_method.strip())

    # track progress
    print("[{}/{}] hits: {} ({},{})"
          .format(
              counter+1,
              limit if limit>0 else df.shape[0],
              res.shape[0],
              test_method.strip(),
              test_item.strip()))
#     breakpoint()
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
        print(res)

    #res[0]: res_id
    #res[1]: res_item
    #res[2]: res_method
    if res.shape[0] == 1:
        if sanitize(res.iloc[0,1]) == sanitize(test_item):
            counter+=1
            print("Perfect Match: {} | {}".format(res.iloc[0,1], test_item))
            return res.iloc[0,0]
        elif (sanitize(res.iloc[0,1]) in sanitize(test_item) or sanitize(test_item) in sanitize(res.iloc[0,1])):
            counter+=1
            print("{} | {}".format(res.iloc[0,1], test_item))
            return res.iloc[0,0]
        else:
            counter+=1
            print("{} | {}".format(res.iloc[0,1], test_item))
            return "{}:{}".format(res.iloc[0,0], res.iloc[0,1])

    elif res.shape[0] > 1:
        res_exact=res[res[2] == test_method.strip()]
        print("exact hits: {}".format(res_exact.shape[0]))
        with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
            print(res_exact)
        if res_exact.shape[0] == 1:
            if sanitize(res_exact.iloc[0,1]) == sanitize(test_item):
                counter+=1
                print("Perfect Match: {} | {}".format(res_exact.iloc[0,1], test_item))
                return res_exact.iloc[0,0]
            elif (sanitize(res_exact.iloc[0,1]) in sanitize(test_item) or sanitize(test_item) in sanitize(res_exact.iloc[0,1])):
                counter+=1
                print("{} | {}".format(res.iloc[0,1], test_item))
                return res_exact.iloc[0,0]
            else:
                print("{} | {}".format(res_exact.iloc[0,1], test_item))
                counter+=1
                return "{}:{}".format(res_exact.iloc[0,0], res_exact.iloc[0,1])
        else:
            counter+=1
            print("{} exact hits".format(res_exact.shape[0]))
            return "{} exact hits".format(res_exact.shape[0])

    else:
        counter+=1
        print("{} hits on initial search".format(res.shape[0]))
        return "{} hits".format(res.shape[0])
    counter+=1
    print("you should never reach this part of first_pass()")
    return "you should never reach this part of first_pass()"

# %%
def main():
    global driver
    global counter
    global limit
    global cached_list
    global df

    df=pd.read_excel("./r2.xlsx", header=None, usecols=[0,1])
    if df.shape[1] == 2:
        df.insert(0,"","")
        df.columns = ["test_id","test_item","test_method"]
    elif df.shape[1] == 3:
        """do nothing"""
    else:
        sys.exit("first_pass() received a dataframe with {} columns (only 2 or 3 is allowed)".format(df.shape[1]))
    df

    # Initialize the chrome webdriver instance
    try:
        driver.current_url
    except:
        driver=prep_driver()
    # driver = ""

    # Initialize the counter and limit. Leave limit as a negative number if you want to loop through the entire 
    counter=0
    limit=-1

    # Note down the available cached search results in a list
    cached_list = [f for f in os.listdir("./data")]
    cached_list = [os.path.splitext(f)[0] for f in cached_list]
    cached_list = []

    df['test_id'] = df.apply(
            lambda row: first_pass(row['test_id'],row['test_item'],row['test_method']),
            axis=1
        )
    counter=0 # reset the counter back to 0

    # export the resultant dataframe to excel
    # df.to_excel("./df1.xlsx", header=None, index=None)
    df

# %%
if __name__ == '__main__':
    main()
# Out:
# BS EN 932-3 added to cached_list
# [1/2] hits: 2 (BS EN 932-3,Petrographic Examination of Aggregates for Concrete)
#         0                         1            2
# 0  ASO158  Petrographic Analysis     BS EN 932-3
# 1  ASO255  Petrographic Examination  BS EN 932-3
# exact hits: 2
#         0                         1            2
# 0  ASO158  Petrographic Analysis     BS EN 932-3
# 1  ASO255  Petrographic Examination  BS EN 932-3
# 2 exact hits
#
# BS 7943 added to cached_list
# [2/1] hits: 1 (BS 7943,Petrographic Examination of Aggregates for Concrete)
#         0                                                    1        2
# 0  T00938  Petrographic Examination of Aggregates for Concrete  BS 7943
# Perfect Match: Petrographic Examination of Aggregates for Concrete | Petrographic Examination of Aggregates for Concrete
#
# BS 812-104 added to cached_list
# [3/1] hits: 1 (BS 812-104,Petrographic Examination of Aggregates for Concrete)
#         0                         1           2
# 0  ASO210  Petrographic Examination  BS 812-104
# Petrographic Examination | Petrographic Examination of Aggregates for Concrete
#
# ASTM C295 added to cached_list
# [4/1] hits: 1 (ASTM C295,Petrographic Examination of Aggregates for Concrete)
#         0                         1          2
# 0  ASO078  Petrographic Examination  ASTM C295
# Petrographic Examination | Petrographic Examination of Aggregates for Concrete
#
# ASTM C1260 added to cached_list
# [5/1] hits: 1 (ASTM C1260,Potential Alkali Reactivity (Mortar Bar Method))
#         0                                               1           2
# 0  ASO049  Potential Alkali Reactivity(Mortar-Bar Method)  ASTM C1260
# Perfect Match: Potential Alkali Reactivity(Mortar-Bar Method) | Potential Alkali Reactivity (Mortar Bar Method)
#
# SS 73 added to cached_list
# [6/22] hits: 22 (SS 73,Particle Size Distribution (Sieve Analysis))
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
#
# ASTM C136 added to cached_list
# [7/5] hits: 5 (ASTM C136,Particle Size Distribution (Sieve Analysis))
#         0                                            1                 2
# 0  T00126  Fineness Modulus                             ASTM C136
# 1  ASO003  Particle Size Distribution (Sieve Analysis)  ASTM C136 & C117
# 2  T00125  Salinity                                     ASTM C136
# 3  ASO165  Sieve Analysis                               ASTM C136
# 4  IPC008  Sieve Analysis                               ASTM C136: 2006
# exact hits: 3
#         0                 1          2
# 0  T00126  Fineness Modulus  ASTM C136
# 2  T00125  Salinity          ASTM C136
# 3  ASO165  Sieve Analysis    ASTM C136
# 3 exact hits
#
# BS 812-103.1 added to cached_list
# [8/3] hits: 3 (BS 812-103.1,Particle Size Distribution (Sieve Analysis))
#         0                                            1             2
# 0  T00491  Particle Size Distribution                   BS 812-103.1
# 1  ASO166  Particle Size Distribution (Sieve Analysis)  BS 812-103.1
# 2  T00067  Silt & Clay Content                          BS 812-103.1
# exact hits: 3
#         0                                            1             2
# 0  T00491  Particle Size Distribution                   BS 812-103.1
# 1  ASO166  Particle Size Distribution (Sieve Analysis)  BS 812-103.1
# 2  T00067  Silt & Clay Content                          BS 812-103.1
# 3 exact hits
#
# BS EN 933-1 added to cached_list
# [9/7] hits: 7 (BS EN 933-1,Particle Size Distribution (Sieve Analysis))
#         0                                            1             2
# 0  T01010  Constituents of Coarse Recycled Aggregates   BS EN 933-11
# 1  ASO256  Fines Content (clay, Silt and dust)          BS EN 933-1
# 2  ASO103  Material Finer                               BS EN 933-10
# 3  ASO050  Particle Size Distribution (Sieve Analysis)  BS EN 933-1
# 4  ASO081  Particle Size Distribution < 2mm             BS EN 933-10
# 5  ASO069  Particle Size Distribution-Wet               BS EN 933-1
# 6  ASO254  Sieve Analysis                               BS EN 933-1
# exact hits: 4
#         0                                            1            2
# 1  ASO256  Fines Content (clay, Silt and dust)          BS EN 933-1
# 3  ASO050  Particle Size Distribution (Sieve Analysis)  BS EN 933-1
# 5  ASO069  Particle Size Distribution-Wet               BS EN 933-1
# 6  ASO254  Sieve Analysis                               BS EN 933-1
# 4 exact hits
#
# ASTM D546 (ASTM D242) added to cached_list
# [10/0] hits: 0 (ASTM D546 (ASTM D242),Particle Size Distribution (Sieve Analysis))
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# ASTM C136 already exists in cached_list
# [11/0] hits: 5 (ASTM C136,Fineness Modulus)
#         0                                            1                 2
# 0  T00126  Fineness Modulus                             ASTM C136
# 1  ASO003  Particle Size Distribution (Sieve Analysis)  ASTM C136 & C117
# 2  T00125  Salinity                                     ASTM C136
# 3  ASO165  Sieve Analysis                               ASTM C136
# 4  IPC008  Sieve Analysis                               ASTM C136: 2006
# exact hits: 3
#         0                 1          2
# 0  T00126  Fineness Modulus  ASTM C136
# 2  T00125  Salinity          ASTM C136
# 3  ASO165  Sieve Analysis    ASTM C136
# 3 exact hits
# SS 73 Cl 13 Method B added to cached_list
# [12/1] hits: 1 (SS 73 Cl 13 Method B,Fines Content (Clay, Silt and Dust) - Decantation Method)
#         0                                                         1  \
# 0  T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
#
#                       2
# 0  SS 73 Cl 13 Method B
# Perfect Match: Fines Content (Clay, Silt and Dust) - Decantation Method | Fines Content (Clay, Silt and Dust) - Decantation Method
#
# SS 73 Cl 14 Method C added to cached_list
# [13/1] hits: 1 (SS 73 Cl 14 Method C,Fines Content (Clay, Silt and Dust) - Field Settling Test)
#         0                                                          1  \
# 0  T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
#
#                       2
# 0  SS 73 Cl 14 Method C
# Perfect Match: Fines Content (Clay, Silt and Dust) - Field Settling Test | Fines Content (Clay, Silt and Dust) - Field Settling Test
#
# BS 812-103.1 already exists in cached_list
# [14/1] hits: 3 (BS 812-103.1,Fines Content (Clay, Silt and Dust))
#         0                                            1             2
# 0  T00491  Particle Size Distribution                   BS 812-103.1
# 1  ASO166  Particle Size Distribution (Sieve Analysis)  BS 812-103.1
# 2  T00067  Silt & Clay Content                          BS 812-103.1
# exact hits: 3
#         0                                            1             2
# 0  T00491  Particle Size Distribution                   BS 812-103.1
# 1  ASO166  Particle Size Distribution (Sieve Analysis)  BS 812-103.1
# 2  T00067  Silt & Clay Content                          BS 812-103.1
# 3 exact hits
#
# ASTM C117 added to cached_list
# [15/1] hits: 1 (ASTM C117,Fines Content (Clay, Silt and Dust))
#         0                            1          2
# 0  ASO149  Materials finer than 75  µm  ASTM C117
# Materials finer than 75  µm | Fines Content (Clay, Silt and Dust)
#
# BS EN 933-1 already exists in cached_list
# [16/1] hits: 7 (BS EN 933-1,Fines Content (Clay, Silt and Dust))
#         0                                            1             2
# 0  T01010  Constituents of Coarse Recycled Aggregates   BS EN 933-11
# 1  ASO256  Fines Content (clay, Silt and dust)          BS EN 933-1
# 2  ASO103  Material Finer                               BS EN 933-10
# 3  ASO050  Particle Size Distribution (Sieve Analysis)  BS EN 933-1
# 4  ASO081  Particle Size Distribution < 2mm             BS EN 933-10
# 5  ASO069  Particle Size Distribution-Wet               BS EN 933-1
# 6  ASO254  Sieve Analysis                               BS EN 933-1
# exact hits: 4
#         0                                            1            2
# 1  ASO256  Fines Content (clay, Silt and dust)          BS EN 933-1
# 3  ASO050  Particle Size Distribution (Sieve Analysis)  BS EN 933-1
# 5  ASO069  Particle Size Distribution-Wet               BS EN 933-1
# 6  ASO254  Sieve Analysis                               BS EN 933-1
# 4 exact hits
#
# SS 73 Cl 28 Method A added to cached_list
# [17/1] hits: 1 (SS 73 Cl 28 Method A,Moisture Content)
#         0                 1                     2
# 0  T00935  Moisture Content  SS 73 Cl 28 Method A
# Perfect Match: Moisture Content | Moisture Content
#
# BS 812-109 added to cached_list
# [18/1] hits: 1 (BS 812-109,Moisture Content)
#         0                 1           2
# 0  ASO146  Moisture content  BS 812-109
# Perfect Match: Moisture content | Moisture Content
#
# BS EN 1097-5 added to cached_list
# [19/1] hits: 1 (BS EN 1097-5,Water Content)
#         0              1             2
# 0  ASO083  Water Content  BS EN 1097-5
# Perfect Match: Water Content | Water Content
#
# BS EN 1097-3 added to cached_list
# [20/1] hits: 1 (BS EN 1097-3,Loose Bulk Density & Void)
#         0                          1             2
# 0  ASO052  Loose Bulk Density & Void  BS EN 1097-3
# Perfect Match: Loose Bulk Density & Void | Loose Bulk Density & Void
#
# BS 812-2 added to cached_list
# [21/9] hits: 9 (BS 812-2,Bulk Density (Compacted and Uncompacted) & Void)
#         0                                           1  \
# 0  ASO119  Bulk Density (Compacted and Loose) & Voids
# 1  ASO239  Particle Density
# 2  ASO156  Particle density  & water absorption
# 3  ASO157  Particle density  & water absorption
# 4  ASO155  Particle density & water absorption
# 5  ASO012  Particle Density of Filler
# 6  ASO019  Uncompacted Bulk Density
# 7  ASO014  Voids & Bulking
# 8  ASO240  Water Absorption
#
#                            2
# 0  BS 812-2
# 1  BS 812-2, Cl 5.4
# 2  BS 812-2, Clause 5.4
# 3  BS 812-2, Clause 5.5
# 4  BS 812-2, Clause 5.3
# 5  BS 812-2, Clause 5.7
# 6  BS 812-2:Clause 6.3
# 7  BS 812-2:Clause 6.4 & 6.5
# 8  BS 812-2 Cl.5.4
# exact hits: 1
#         0                                           1         2
# 0  ASO119  Bulk Density (Compacted and Loose) & Voids  BS 812-2
# Bulk Density (Compacted and Loose) & Voids | Bulk Density (Compacted and Uncompacted) & Void
#
# SS 73 already exists in cached_list
# [22/9] hits: 22 (SS 73,Bulk Density (Compacted and Uncompacted) & Void)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
# BS EN 1097-6 added to cached_list
# [23/4] hits: 4 (BS EN 1097-6,Particle Density & Water Absorption)
#         0                                    1                   2
# 0  ASO051  Density & Water Absorption           BS EN 1097-6, Cl 9
# 1  ASO082  Density & Water Absorption           BS EN 1097-6, Cl 8
# 2  ASO258  Specific gravity & Water Absorption  BS EN 1097-6
# 3  ASO177  Thermal and weathering properties    BS EN 1097-6
# exact hits: 2
#         0                                    1             2
# 2  ASO258  Specific gravity & Water Absorption  BS EN 1097-6
# 3  ASO177  Thermal and weathering properties    BS EN 1097-6
# 2 exact hits
#
# BS 812-2 already exists in cached_list
# [24/4] hits: 9 (BS 812-2,Particle Density & Water Absorption)
#         0                                           1  \
# 0  ASO119  Bulk Density (Compacted and Loose) & Voids
# 1  ASO239  Particle Density
# 2  ASO156  Particle density  & water absorption
# 3  ASO157  Particle density  & water absorption
# 4  ASO155  Particle density & water absorption
# 5  ASO012  Particle Density of Filler
# 6  ASO019  Uncompacted Bulk Density
# 7  ASO014  Voids & Bulking
# 8  ASO240  Water Absorption
#
#                            2
# 0  BS 812-2
# 1  BS 812-2, Cl 5.4
# 2  BS 812-2, Clause 5.4
# 3  BS 812-2, Clause 5.5
# 4  BS 812-2, Clause 5.3
# 5  BS 812-2, Clause 5.7
# 6  BS 812-2:Clause 6.3
# 7  BS 812-2:Clause 6.4 & 6.5
# 8  BS 812-2 Cl.5.4
# exact hits: 1
#         0                                           1         2
# 0  ASO119  Bulk Density (Compacted and Loose) & Voids  BS 812-2
# Bulk Density (Compacted and Loose) & Voids | Particle Density & Water Absorption
#
# SS 73 already exists in cached_list
# [25/4] hits: 22 (SS 73,Particle Density & Water Absorption)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
#
# ASTM C127 added to cached_list
# [26/2] hits: 2 (ASTM C127,Relative Density (Specific Gravity) & Water Absorption)
#         0                                     1          2
# 0  ASO169  Particle Density & Water Absorption   ASTM C127
# 1  T01201  Water Absorption of Coarse Aggregate  ASTM C127
# exact hits: 2
#         0                                     1          2
# 0  ASO169  Particle Density & Water Absorption   ASTM C127
# 1  T01201  Water Absorption of Coarse Aggregate  ASTM C127
# 2 exact hits
#
# ASTM C128 Gravimetric Method added to cached_list
# [27/0] hits: 0 (ASTM C128 Gravimetric Method,Relative Density (Specific Gravity) & Water Absorption)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 932-1 added to cached_list
# [28/1] hits: 1 (BS EN 932-1,Sampling)
#         0                    1            2
# 0  T00941  Sampling Aggregates  BS EN 932-1
# Sampling Aggregates | Sampling
#
# BS 812-102 added to cached_list
# [29/1] hits: 1 (BS 812-102,Sampling)
#         0                    1           2
# 0  T00986  Sampling Aggregates  BS 812-102
# Sampling Aggregates | Sampling
#
# SS 73 already exists in cached_list
# [30/1] hits: 22 (SS 73,Sampling)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
# ASTM C40 added to cached_list
# [31/5] hits: 5 (ASTM C40,Organic Impurites)
#         0                                                               1  \
# 0  CSR061  Organic Impurities
# 1  CHM043  Organic impurities in sand
# 2  ASO191  Organic Impurities in Sand
# 3  T00005  Setting Time
# 4  CON011  Time of Setting of Concrete Mixtures by Penetration Resistance
#
#                  2
# 0  ASTM C40
# 1  ASTM C40: 2004
# 2  ASTM C40
# 3  ASTM C403
# 4  ASTM C403/C403M
# exact hits: 2
#         0                           1         2
# 0  CSR061  Organic Impurities          ASTM C40
# 2  ASO191  Organic Impurities in Sand  ASTM C40
# 2 exact hits
#
# SS 73 already exists in cached_list
# [32/5] hits: 22 (SS 73,Organic Impurites)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
#
# SS 73 Part 6 added to cached_list
# [33/1] hits: 1 (SS 73 Part 6,Shell Content)
#         0              1             2
# 0  T00988  Shell Content  SS 73 Part 6
# Perfect Match: Shell Content | Shell Content
#
# BS 812-106 added to cached_list
# [34/1] hits: 1 (BS 812-106,Shell Content)
#         0              1           2
# 0  ASO167  Shell content  BS 812-106
# Perfect Match: Shell content | Shell Content
#
# BS EN 933-7 added to cached_list
# [35/2] hits: 2 (BS EN 933-7,Shell Content)
#         0              1            2
# 0  ASO213  Shell Content  BS EN 933-7
# 1  ASO257  Shell Content  BS EN 933-7
# exact hits: 2
#         0              1            2
# 0  ASO213  Shell Content  BS EN 933-7
# 1  ASO257  Shell Content  BS EN 933-7
# 2 exact hits
#
# SS 73 Part 5.1 added to cached_list
# [36/0] hits: 0 (SS 73 Part 5.1,Flakiness Index)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 933-3 added to cached_list
# [37/2] hits: 2 (BS EN 933-3,Flakiness Index)
#         0                1            2
# 0  ASO053  Flakiness Index  BS EN 933-3
# 1  ASO118  Flakiness Index  BS EN 933-3
# exact hits: 2
#         0                1            2
# 0  ASO053  Flakiness Index  BS EN 933-3
# 1  ASO118  Flakiness Index  BS EN 933-3
# 2 exact hits
#
# BS 812-105.1 added to cached_list
# [38/1] hits: 1 (BS 812-105.1,Flakiness Index)
#         0                1             2
# 0  ASO135  Flakiness Index  BS 812-105.1
# Perfect Match: Flakiness Index | Flakiness Index
#
# SS 73 already exists in cached_list
# [39/1] hits: 22 (SS 73,Elongation Index)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
# BS 812-105.2 added to cached_list
# [40/1] hits: 1 (BS 812-105.2,Elongation Index)
#         0                 1             2
# 0  ASO132  Elongation Index  BS 812-105.2
# Perfect Match: Elongation Index | Elongation Index
#
# SS 73 already exists in cached_list
# [41/1] hits: 22 (SS 73,Aggregate Impact Value)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
#
# BS 812-112 added to cached_list
# [42/1] hits: 1 (BS 812-112,Aggregate Impact Value)
#         0                       1           2
# 0  ASO125  Aggregate Impact Value  BS 812-112
# Perfect Match: Aggregate Impact Value | Aggregate Impact Value
#
# SS 73 already exists in cached_list
# [43/1] hits: 22 (SS 73,Aggregate Crushing Value)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
#
# BS 812-110 added to cached_list
# [44/1] hits: 1 (BS 812-110,Aggregate Crushing Value)
#         0                         1           2
# 0  ASO124  Aggregate Crushing Value  BS 812-110
# Perfect Match: Aggregate Crushing Value | Aggregate Crushing Value
#
# SS 73 already exists in cached_list
# [45/1] hits: 22 (SS 73,10% Fines Value)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
# BS 812-111 added to cached_list
# [46/1] hits: 1 (BS 812-111,10% Fines Value)
#         0                        1           2
# 0  ASO174  Ten percent fines value  BS 812-111
# Ten percent fines value | 10% Fines Value
#
# SS 73 already exists in cached_list
# [47/1] hits: 22 (SS 73,Los Angeles Abrasion)
#          0                                                          1  \
# 0   T00193  10% Fines Value (TFV)
# 1   T00131  Acid Soluble Sulphate Content
# 2   T00194  Aggregate Crushing Value (ACV)
# 3   T00998  Aggregate Impact Value
# 4   T01009  Angularity Number
# 5   T00994  Bulk Density (Compacted and Loose) & Voids
# 6   T00932  Drying Shrinkage
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# ...
# 7   T00996  Elongation Index
# 8   T00992  Fines Content (Clay, Silt and Dust) - Decantation Method
# 9   T00993  Fines Content (Clay, Silt and Dust) - Field Settling Test
# 10  T00132  Flakiness Index (FI)
# 11  T00195  Los Angeles Abrasion (LA)
# 12  T00935  Moisture Content
# 13  T00196  Organic Impurities
# 14  T00197  Particle Density & Water Absorption
# 15  T00198  Particle Size Distribution (Sieve Analysis)
# 16  T00987  Sampling
# 17  T00199  Shape & Surface Texture
# 18  T00988  Shell Content
# 19  T00989  Total Sulfate Content by Acid Extraction
# 20  T00995  Water-soluble Chloride Salts
# 21  T00999  Water-soluble Sulfates
#
#                        2
# 0   SS 73
# 1   SS 73 Pt 18
# 2   SS 73
# 3   SS 73
# 4   SS 73
# 5   SS 73
# 6   SS 73 Part 20
# 7   SS 73
# 8   SS 73 Cl 13 Method B
# 9   SS 73 Cl 14 Method C
# 10  SS 73-5.1
# 11  SS 73
# 12  SS 73 Cl 28 Method A
# 13  SS 73
# 14  SS 73
# 15  SS 73
# 16  SS 73
# 17  SS 73
# 18  SS 73 Part 6
# 19  SS 73: Part 18 Cl 6
# 20  SS 73: Part 17
# 21  SS 73: Part 18 Cl 5
# exact hits: 12
#          0                                            1      2
# 0   T00193  10% Fines Value (TFV)                        SS 73
# 2   T00194  Aggregate Crushing Value (ACV)               SS 73
# 3   T00998  Aggregate Impact Value                       SS 73
# 4   T01009  Angularity Number                            SS 73
# 5   T00994  Bulk Density (Compacted and Loose) & Voids   SS 73
# 7   T00996  Elongation Index                             SS 73
# 11  T00195  Los Angeles Abrasion (LA)                    SS 73
# 13  T00196  Organic Impurities                           SS 73
# 14  T00197  Particle Density & Water Absorption          SS 73
# 15  T00198  Particle Size Distribution (Sieve Analysis)  SS 73
# 16  T00987  Sampling                                     SS 73
# 17  T00199  Shape & Surface Texture                      SS 73
# 12 exact hits
#
# BS EN 933-8 added to cached_list
# [62/1] hits: 1 (BS EN 933-8,Assessment of Fines - Sand Equivalent Test)
#         0                                           1            2
# 0  T01035  Assessment of Fines - Sand Equivalent Test  BS EN 933-8
# Perfect Match: Assessment of Fines - Sand Equivalent Test | Assessment of Fines - Sand Equivalent Test
#
# ASTM D2419 added to cached_list
# [63/1] hits: 1 (ASTM D2419,Assessment of Fines - Sand Equivalent Test)
#         0                      1           2
# 0  ASO168  Sand Equivalent Value  ASTM D2419
# Sand Equivalent Value | Assessment of Fines - Sand Equivalent Test
#
# BS EN 933-11 added to cached_list
# [64/1] hits: 1 (BS EN 933-11,Constituents of Coarse Recycled Aggregates)
#         0                                           1             2
# 0  T01010  Constituents of Coarse Recycled Aggregates  BS EN 933-11
# Perfect Match: Constituents of Coarse Recycled Aggregates | Constituents of Coarse Recycled Aggregates
#
# SS 544.. Part 2 Annex B added to cached_list
# [65/1] hits: 1 (SS 544: Part 2 Annex B,Constituents of Coarse Recycled Aggregates)
#         0                                           1                       2
# 0  T01011  Constituents of Coarse Recycled Aggregates  SS 544: Part 2 Annex B
# Perfect Match: Constituents of Coarse Recycled Aggregates | Constituents of Coarse Recycled Aggregates
#
# BS EN 1744-1 Cl 15.3 added to cached_list
# [66/0] hits: 0 (BS EN 1744-1 Cl 15.3,Organic Contaminators by Mortar Method)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# SANS 5840 added to cached_list
# [67/1] hits: 1 (SANS 5840,Shell/Coral Content)
#         0                      1          2
# 0  T00068  Shell / Coral Content  SANS 5840
# Perfect Match: Shell / Coral Content | Shell/Coral Content
#
# BS 812-113 added to cached_list
# [68/1] hits: 1 (BS 812-113,Aggregate Abrasion Value)
#         0                         1           2
# 0  ASO215  Aggregate Abrasion Value  BS 812-113
# Perfect Match: Aggregate Abrasion Value | Aggregate Abrasion Value
#
# BS EN 1097-8 Annex A added to cached_list
# [69/1] hits: 1 (BS EN 1097-8 Annex A,Aggregate Abrasion Value)
#         0                         1                     2
# 0  T01014  Aggregate Abrasion Value  BS EN 1097-8 Annex A
# Perfect Match: Aggregate Abrasion Value | Aggregate Abrasion Value
#
# BS EN 1744-6 added to cached_list
# [70/1] hits: 1 (BS EN 1744-6,Influence of Recycled Aggregate Extract on the Initial Setting Time of Cement)
#         0  \
# 0  T01016
#
#                                                                                1  \
# 0  Influence of Recycled Aggregate Extract on the Initial Setting Time of Cement
#
#               2
# 0  BS EN 1744-6
# Perfect Match: Influence of Recycled Aggregate Extract on the Initial Setting Time of Cement | Influence of Recycled Aggregate Extract on the Initial Setting Time of Cement
#
# ASTM D5821 added to cached_list
# [71/1] hits: 1 (ASTM D5821,Percentage of Fractured Particles in Coarse Aggregate)
#         0                                                      1           2
# 0  ASO004  Percentage of Fractured Particles in Coarse Aggregate  ASTM D5821
# Perfect Match: Percentage of Fractured Particles in Coarse Aggregate | Percentage of Fractured Particles in Coarse Aggregate
#
# ASTM D4791 added to cached_list
# [72/1] hits: 1 (ASTM D4791,Flat Particles, Elongated Particles, or Flat and Elongated Particles in Coarse Aggregate)
#         0                             1           2
# 0  ASO016  Flat and Elongated Particles  ASTM D4791
# Flat and Elongated Particles | Flat Particles, Elongated Particles, or Flat and Elongated Particles in Coarse Aggregate
#
# ASTM C142 added to cached_list
# [73/1] hits: 1 (ASTM C142,Clay Lumps and Friable Particles in Aggregates)
#         0                               1          2
# 0  ASO126  Clay Lumps & Friable Particles  ASTM C142
# Clay Lumps & Friable Particles | Clay Lumps and Friable Particles in Aggregates
# BS EN 1097-8 added to cached_list
# [74/3] hits: 3 (BS EN 1097-8,Polished Stone Value)
#         0                               1                     2
# 0  T01014  Aggregate Abrasion Value        BS EN 1097-8 Annex A
# 1  T01038  Aggregate Abrasion Value (AAV)  BS EN 1097-8 Annex 8
# 2  ASO244  Polished Stone Value (PSV)      BS EN 1097-8
# exact hits: 1
#         0                           1             2
# 2  ASO244  Polished Stone Value (PSV)  BS EN 1097-8
# Aggregate Abrasion Value | Polished Stone Value
#
# BS 812-114 added to cached_list
# [75/1] hits: 1 (BS 812-114,Polished Stone Value)
#         0                       1           2
# 0  ASO113  Polished - Stone Value  BS 812-114
# Perfect Match: Polished - Stone Value | Polished Stone Value
#
# ASTM C123 added to cached_list
# [76/2] hits: 2 (ASTM C123,Lightweight Particles in Aggregate)
#         0                              1          2
# 0  CHE016  Lightweight Particle Analysis  ASTM C123
# 1  ASO143  Lightweight pieces             ASTM C123
# exact hits: 2
#         0                              1          2
# 0  CHE016  Lightweight Particle Analysis  ASTM C123
# 1  ASO143  Lightweight pieces             ASTM C123
# 2 exact hits
#
# ASTM C1105 added to cached_list
# [77/3] hits: 3 (ASTM C1105,Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days)
#         0  \
# 0  T01019
# 1  T01017
# 2  T01018
#
#                                                                                   1  \
# 0  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year
# 1  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days
# 2  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months
#
#             2
# 0  ASTM C1105
# 1  ASTM C1105
# 2  ASTM C1105
# exact hits: 3
#         0  \
# 0  T01019
# 1  T01017
# 2  T01018
#
#                                                                                   1  \
# 0  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year
# 1  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days
# 2  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months
#
#             2
# 0  ASTM C1105
# 1  ASTM C1105
# 2  ASTM C1105
# 3 exact hits
#
# ASTM C1105 already exists in cached_list
# [78/3] hits: 3 (ASTM C1105,Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months)
#         0  \
# 0  T01019
# 1  T01017
# 2  T01018
#
#                                                                                   1  \
# 0  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year
# 1  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days
# 2  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months
#
#             2
# 0  ASTM C1105
# 1  ASTM C1105
# 2  ASTM C1105
# exact hits: 3
#         0  \
# 0  T01019
# 1  T01017
# 2  T01018
#
#                                                                                   1  \
# 0  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year
# 1  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days
# 2  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months
#
#             2
# 0  ASTM C1105
# 1  ASTM C1105
# 2  ASTM C1105
# 3 exact hits
#
# ASTM C1105 already exists in cached_list
# [79/3] hits: 3 (ASTM C1105,Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year)
#         0  \
# 0  T01019
# 1  T01017
# 2  T01018
#
#                                                                                   1  \
# 0  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year
# 1  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days
# 2  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months
#
#             2
# 0  ASTM C1105
# 1  ASTM C1105
# 2  ASTM C1105
# exact hits: 3
#         0  \
# 0  T01019
# 1  T01017
# 2  T01018
#
#                                                                                   1  \
# 0  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 1 year
# 1  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 56 days
# 2  Length Change of Concrete Due to Alkali-Carbonate Rock Reaction - Up to 6 months
#
#             2
# 0  ASTM C1105
# 1  ASTM C1105
# 2  ASTM C1105
# 3 exact hits
#
# SS 73.. Part 17 added to cached_list
# [80/1] hits: 1 (SS 73: Part 17,Water-soluble Chloride Salts)
#         0                             1               2
# 0  T00995  Water-soluble Chloride Salts  SS 73: Part 17
# Perfect Match: Water-soluble Chloride Salts | Water-soluble Chloride Salts
#
# BS 812-117 added to cached_list
# [81/0] hits: 0 (BS 812-117,Water-soluble Chloride Salts)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 1744-1 Cl 7 added to cached_list
# [82/1] hits: 1 (BS EN 1744-1 Cl 7,Water-soluble Chloride Salts)
#         0                             1                  2
# 0  T00997  Water-soluble Chloride Salts  BS EN 1744-1 Cl 7
# Perfect Match: Water-soluble Chloride Salts | Water-soluble Chloride Salts
#
# BS EN 1744-5 added to cached_list
# [83/1] hits: 1 (BS EN 1744-5,Acid Soluble Chloride Salts)
#         0                            1             2
# 0  ASO046  Acid Soluble Chloride Salts  BS EN 1744-5
# Perfect Match: Acid Soluble Chloride Salts | Acid Soluble Chloride Salts
#
# SS 73.. Part 18 Cl 5 Gravimetric Method added to cached_list
# [84/0] hits: 0 (SS 73: Part 18 Cl 5 Gravimetric Method,Water-soluble Sulfates)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# SS 73.. Part 18 Cl 6 added to cached_list
# [85/1] hits: 1 (SS 73: Part 18 Cl 6,Total Sulfate Content by Acid Extraction)
#         0                                         1                    2
# 0  T00989  Total Sulfate Content by Acid Extraction  SS 73: Part 18 Cl 6
# Perfect Match: Total Sulfate Content by Acid Extraction | Total Sulfate Content by Acid Extraction
#
# BS 812-118 Cl 5 Gravimetric Method added to cached_list
# [86/0] hits: 0 (BS 812-118 Cl 5 Gravimetric Method,Water-soluble Sulfates)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS 812-118 Cl 6 added to cached_list
# [87/1] hits: 1 (BS 812-118 Cl 6,Total Sulfate Content by Acid Extraction)
#         0                                         1                2
# 0  ASO192  Total Sulfate Content by Acid Extraction  BS 812-118 Cl 6
# Perfect Match: Total Sulfate Content by Acid Extraction | Total Sulfate Content by Acid Extraction
#
# BS EN 1744-1 Cl 10.1 added to cached_list
# [88/0] hits: 0 (BS EN 1744-1 Cl 10.1,Water-soluble Sulfates)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 1744-1 Cl 10.2 added to cached_list
# [89/0] hits: 0 (BS EN 1744-1 Cl 10.2,Water-soluble Sulfates)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 1744-1 Cl 12 added to cached_list
# [90/0] hits: 0 (BS EN 1744-1 Cl 12,Acid Soluble Sulfates)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 1744-1 Cl 11 added to cached_list
# [91/0] hits: 0 (BS EN 1744-1 Cl 11,Total Sulfur Content)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# BS EN 1744-1 Cl 13 added to cached_list
# [92/1] hits: 1 (BS EN 1744-1 Cl 13,Acid Soluble Sulfides)
#         0                      1                   2
# 0  ASO089  Acid Soluble Sulfides  BS EN 1744-1 Cl 13
# Perfect Match: Acid Soluble Sulfides | Acid Soluble Sulfides
#
# ASTM C289 added to cached_list
# [93/1] hits: 1 (ASTM C289,Potential Alkali Silica Reactivity (Chemical Method))
#         0                                                     1          2
# 0  ASO194  Potential Alkali Silica Reactivity (Chemical Method)  ASTM C289
# Perfect Match: Potential Alkali Silica Reactivity (Chemical Method) | Potential Alkali Silica Reactivity (Chemical Method)
#
# BS EN 1744-1 Cl 14.2 added to cached_list
# [94/1] hits: 1 (BS EN 1744-1 Cl 14.2,Lightweight Organic Contaminator)
#         0                                 1                     2
# 0  T01088  Lightweight Organic Contaminator  BS EN 1744-1 Cl 14.2
# Perfect Match: Lightweight Organic Contaminator | Lightweight Organic Contaminator
# BS EN 1744-1 Cl 15.1 added to cached_list
# [95/1] hits: 1 (BS EN 1744-1 Cl 15.1,Potential Presence of Humus)
#         0                            1                     2
# 0  T00939  Potential Presence of Humus  BS EN 1744-1 Cl 15.1
# Perfect Match: Potential Presence of Humus | Potential Presence of Humus
#
# BS EN 1744-1 Cl 15.2 added to cached_list
# [96/1] hits: 1 (BS EN 1744-1 Cl 15.2,Fulvo Acid Content)
#         0                   1                     2
# 0  T01020  Fulvo Acid Content  BS EN 1744-1 Cl 15.2
# Perfect Match: Fulvo Acid Content | Fulvo Acid Content
#
# BS EN 1744-1 Cl 17 added to cached_list
# [97/0] hits: 0 (BS EN 1744-1 Cl 17,Loss on Ignition)
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search
#
# ASTM C637 Cl 9.1.3.1 added to cached_list
# [98/1] hits: 1 (ASTM C637 Cl 9.1.3.1,Fixed Water Content by Ignition Test)
#         0                                     1                     2
# 0  T01021  Fixed Water Content by Ignition Test  ASTM C637 Cl 9.1.3.1
# Perfect Match: Fixed Water Content by Ignition Test | Fixed Water Content by Ignition Test
#
# ED-XRF added to cached_list
# [99/0] hits: 0 (ED-XRF,Elemental Analysis (Semi-Quantitative))
# Empty DataFrame
# Columns: []
# Index: []
# 0 hits on initial search

# %%
df_z = df.copy()

# %%
df=pd.read_excel("./r2.xlsx", header=None, usecols=[0,1])
df
# Out:
#                                                     0  \
# 0   Petrographic Examination of Aggregates for Con...
# 1   Petrographic Examination of Aggregates for Con...
# 2   Petrographic Examination of Aggregates for Con...
# 3   Petrographic Examination of Aggregates for Con...
# 4     Potential Alkali Reactivity (Mortar Bar Method)
# 5         Particle Size Distribution (Sieve Analysis)
# 6         Particle Size Distribution (Sieve Analysis)
# 7         Particle Size Distribution (Sieve Analysis)
# 8         Particle Size Distribution (Sieve Analysis)
# 9         Particle Size Distribution (Sieve Analysis)
# 10                                   Fineness Modulus
# 11  Fines Content (Clay, Silt and Dust) - Decantat...
# 12  Fines Content (Clay, Silt and Dust) - Field Se...
# 13                Fines Content (Clay, Silt and Dust)
# 14                Fines Content (Clay, Silt and Dust)
# 15                Fines Content (Clay, Silt and Dust)
# 16                                   Moisture Content
# 17                                   Moisture Content
# 18                                      Water Content
# 19                          Loose Bulk Density & Void
# 20    Bulk Density (Compacted and Uncompacted) & Void
# 21    Bulk Density (Compacted and Uncompacted) & Void
# 22                Particle Density & Water Absorption
# 23                Particle Density & Water Absorption
# 24                Particle Density & Water Absorption
# 25  Relative Density (Specific Gravity) & Water Ab...
# 26  Relative Density (Specific Gravity) & Water Ab...
# 27                                           Sampling
# 28                                           Sampling
# 29                                           Sampling
# ..                                                ...
# 69  Influence of Recycled Aggregate Extract on the...
# 70  Percentage of Fractured Particles in Coarse Ag...
# 71  Flat Particles, Elongated Particles, or Flat a...
# 72     Clay Lumps and Friable Particles in Aggregates
# 73                               Polished Stone Value
# 74                               Polished Stone Value
# 75                 Lightweight Particles in Aggregate
# 76  Length Change of Concrete Due to Alkali-Carbon...
# 77  Length Change of Concrete Due to Alkali-Carbon...
# 78  Length Change of Concrete Due to Alkali-Carbon...
# 79                       Water-soluble Chloride Salts
# 80                       Water-soluble Chloride Salts
# 81                       Water-soluble Chloride Salts
# 82                       Acid Soluble Chloride Salts
# 83                             Water-soluble Sulfates
# 84           Total Sulfate Content by Acid Extraction
# 85                             Water-soluble Sulfates
# 86           Total Sulfate Content by Acid Extraction
# 87                             Water-soluble Sulfates
# 88                             Water-soluble Sulfates
# 89                              Acid Soluble Sulfates
# 90                               Total Sulfur Content
# 91                              Acid Soluble Sulfides
# 92  Potential Alkali Silica Reactivity (Chemical M...
# 93                   Lightweight Organic Contaminator
# 94                        Potential Presence of Humus
# 95                                 Fulvo Acid Content
# 96                                   Loss on Ignition
# 97               Fixed Water Content by Ignition Test
# 98             Elemental Analysis (Semi-Quantitative)
#
#                                                     1
# 0                  BS EN 932-3
# 1                                             BS 7943
# 2   BS 812-104                                    ...
# 3                                           ASTM C295
# 4                                          ASTM C1260
# 5                      SS 73
# 6                                           ASTM C136
# 7                                        BS 812-103.1
# 8                                         BS EN 933-1
# 9                               ASTM D546 (ASTM D242)
# 10                                          ASTM C136
# 11                               SS 73 Cl 13 Method B
# 12                               SS 73 Cl 14 Method C
# 13                                       BS 812-103.1
# 14                                          ASTM C117
# 15                                        BS EN 933-1
# 16                               SS 73 Cl 28 Method A
# 17                                         BS 812-109
# 18                                       BS EN 1097-5
# 19                                       BS EN 1097-3
# 20                                           BS 812-2
# 21                                              SS 73
# 22                                       BS EN 1097-6
# 23                                           BS 812-2
# 24                                              SS 73
# 25                                          ASTM C127
# 26                       ASTM C128 Gravimetric Method
# 27                     BS EN 932-1
# 28                                         BS 812-102
# 29                                              SS 73
# ..                                                ...
# 69                                       BS EN 1744-6
# 70                                         ASTM D5821
# 71                                         ASTM D4791
# 72                                          ASTM C142
# 73                                       BS EN 1097-8
# 74                                         BS 812-114
# 75                                          ASTM C123
# 76                                         ASTM C1105
# 77                                         ASTM C1105
# 78                                         ASTM C1105
# 79                                     SS 73: Part 17
# 80                                         BS 812-117
# 81                                  BS EN 1744-1 Cl 7
# 82                                       BS EN 1744-5
# 83             SS 73: Part 18 Cl 5 Gravimetric Method
# 84                                SS 73: Part 18 Cl 6
# 85                 BS 812-118 Cl 5 Gravimetric Method
# 86                                    BS 812-118 Cl 6
# 87                               BS EN 1744-1 Cl 10.1
# 88                               BS EN 1744-1 Cl 10.2
# 89                                 BS EN 1744-1 Cl 12
# 90                                 BS EN 1744-1 Cl 11
# 91                                 BS EN 1744-1 Cl 13
# 92                                          ASTM C289
# 93                               BS EN 1744-1 Cl 14.2
# 94                               BS EN 1744-1 Cl 15.1
# 95                               BS EN 1744-1 Cl 15.2
# 96                                 BS EN 1744-1 Cl 17
# 97                               ASTM C637 Cl 9.1.3.1
# 98                                             ED-XRF
#
# [99 rows x 2 columns]

# %%
if df.shape[1] == 2:
    df.insert(0,"","")
    df.columns = ["test_id","test_item","test_method"]
elif df.shape[1] == 3:
    """do nothing"""
else:
    sys.exit("first_pass() received a dataframe with {} columns (only 2 or 3 is allowed)".format(df.shape[1]))
df
# Out:
#    test_id                                          test_item  \
# 0           Petrographic Examination of Aggregates for Con...
# 1           Petrographic Examination of Aggregates for Con...
# 2           Petrographic Examination of Aggregates for Con...
# 3           Petrographic Examination of Aggregates for Con...
# 4             Potential Alkali Reactivity (Mortar Bar Method)
# 5                 Particle Size Distribution (Sieve Analysis)
# 6                 Particle Size Distribution (Sieve Analysis)
# 7                 Particle Size Distribution (Sieve Analysis)
# 8                 Particle Size Distribution (Sieve Analysis)
# 9                 Particle Size Distribution (Sieve Analysis)
# 10                                           Fineness Modulus
# 11          Fines Content (Clay, Silt and Dust) - Decantat...
# 12          Fines Content (Clay, Silt and Dust) - Field Se...
# 13                        Fines Content (Clay, Silt and Dust)
# 14                        Fines Content (Clay, Silt and Dust)
# 15                        Fines Content (Clay, Silt and Dust)
# 16                                           Moisture Content
# 17                                           Moisture Content
# 18                                              Water Content
# 19                                  Loose Bulk Density & Void
# 20            Bulk Density (Compacted and Uncompacted) & Void
# 21            Bulk Density (Compacted and Uncompacted) & Void
# 22                        Particle Density & Water Absorption
# 23                        Particle Density & Water Absorption
# 24                        Particle Density & Water Absorption
# 25          Relative Density (Specific Gravity) & Water Ab...
# 26          Relative Density (Specific Gravity) & Water Ab...
# 27                                                   Sampling
# 28                                                   Sampling
# 29                                                   Sampling
# ..     ...                                                ...
# 69          Influence of Recycled Aggregate Extract on the...
# 70          Percentage of Fractured Particles in Coarse Ag...
# 71          Flat Particles, Elongated Particles, or Flat a...
# 72             Clay Lumps and Friable Particles in Aggregates
# 73                                       Polished Stone Value
# 74                                       Polished Stone Value
# 75                         Lightweight Particles in Aggregate
# 76          Length Change of Concrete Due to Alkali-Carbon...
# 77          Length Change of Concrete Due to Alkali-Carbon...
# 78          Length Change of Concrete Due to Alkali-Carbon...
# 79                               Water-soluble Chloride Salts
# 80                               Water-soluble Chloride Salts
# 81                               Water-soluble Chloride Salts
# 82                               Acid Soluble Chloride Salts
# 83                                     Water-soluble Sulfates
# 84                   Total Sulfate Content by Acid Extraction
# 85                                     Water-soluble Sulfates
# 86                   Total Sulfate Content by Acid Extraction
# 87                                     Water-soluble Sulfates
# 88                                     Water-soluble Sulfates
# 89                                      Acid Soluble Sulfates
# 90                                       Total Sulfur Content
# 91                                      Acid Soluble Sulfides
# 92          Potential Alkali Silica Reactivity (Chemical M...
# 93                           Lightweight Organic Contaminator
# 94                                Potential Presence of Humus
# 95                                         Fulvo Acid Content
# 96                                           Loss on Ignition
# 97                       Fixed Water Content by Ignition Test
# 98                     Elemental Analysis (Semi-Quantitative)
#
#                                           test_method
# 0                  BS EN 932-3
# 1                                             BS 7943
# 2   BS 812-104                                    ...
# 3                                           ASTM C295
# 4                                          ASTM C1260
# 5                      SS 73
# 6                                           ASTM C136
# 7                                        BS 812-103.1
# 8                                         BS EN 933-1
# 9                               ASTM D546 (ASTM D242)
# 10                                          ASTM C136
# 11                               SS 73 Cl 13 Method B
# 12                               SS 73 Cl 14 Method C
# 13                                       BS 812-103.1
# 14                                          ASTM C117
# 15                                        BS EN 933-1
# 16                               SS 73 Cl 28 Method A
# 17                                         BS 812-109
# 18                                       BS EN 1097-5
# 19                                       BS EN 1097-3
# 20                                           BS 812-2
# 21                                              SS 73
# 22                                       BS EN 1097-6
# 23                                           BS 812-2
# 24                                              SS 73
# 25                                          ASTM C127
# 26                       ASTM C128 Gravimetric Method
# 27                     BS EN 932-1
# 28                                         BS 812-102
# 29                                              SS 73
# ..                                                ...
# 69                                       BS EN 1744-6
# 70                                         ASTM D5821
# 71                                         ASTM D4791
# 72                                          ASTM C142
# 73                                       BS EN 1097-8
# 74                                         BS 812-114
# 75                                          ASTM C123
# 76                                         ASTM C1105
# 77                                         ASTM C1105
# 78                                         ASTM C1105
# 79                                     SS 73: Part 17
# 80                                         BS 812-117
# 81                                  BS EN 1744-1 Cl 7
# 82                                       BS EN 1744-5
# 83             SS 73: Part 18 Cl 5 Gravimetric Method
# 84                                SS 73: Part 18 Cl 6
# 85                 BS 812-118 Cl 5 Gravimetric Method
# 86                                    BS 812-118 Cl 6
# 87                               BS EN 1744-1 Cl 10.1
# 88                               BS EN 1744-1 Cl 10.2
# 89                                 BS EN 1744-1 Cl 12
# 90                                 BS EN 1744-1 Cl 11
# 91                                 BS EN 1744-1 Cl 13
# 92                                          ASTM C289
# 93                               BS EN 1744-1 Cl 14.2
# 94                               BS EN 1744-1 Cl 15.1
# 95                               BS EN 1744-1 Cl 15.2
# 96                                 BS EN 1744-1 Cl 17
# 97                               ASTM C637 Cl 9.1.3.1
# 98                                             ED-XRF
#
# [99 rows x 3 columns]
